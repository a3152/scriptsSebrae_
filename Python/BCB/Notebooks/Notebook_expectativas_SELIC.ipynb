# %%
from bcb import sgs
seta = sgs.get({'SELICTARGET': 432}, start = '2022-01-01')

# %%
seta.head()
# Out:
#             SELICTARGET
# Date
# 2022-01-01         9.25
# 2022-01-02         9.25
# 2022-01-03         9.25
# 2022-01-04         9.25
# 2022-01-05         9.25

# %%
seta.plot(ylabel='SELICTARGET (%)', xlabel='Date', figsize=(16, 6)).legend('lower right')
